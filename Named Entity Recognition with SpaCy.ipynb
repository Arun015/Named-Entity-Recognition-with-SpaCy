# %%
import spacy
from spacy import displacy
from pprint import pprint
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(" Amid ongoing border tensions, China has once again provoked India and this time Beijing has said that it has never recognised Arunachal Pradesh claiming it to be a part of China's' south Tibet region. State-run Global Times quoted  Chinese Foreign Ministry spokesperson Zhao Lijian as saying that, "China has never recognized so-called "Arunachal Pradesh." which is China's south Tibet region.")
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
#   File "<ipython-input-32-58d6cf736c8b>", line 1
#     doc = nlp(' Amid ongoing border tensions, China has once again provoked India and this time Beijing has said that it has never recognised Arunachal Pradesh claiming it to be a 'part of China's south Tibet region'.
#                                                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'B', 'MONEY'),
#  (record, 'I', 'MONEY'),
#  ($, 'I', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', '')]

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://www.timesnownews.com/india/article/china-has-never-recognised-arunachal-pradesh-beijing-provokes-india-amid-ongoing-border-dispute/648965')

# %%
article = nlp(ny_bb)
len(article.ents)
# Out:
# 175

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'GPE': 41,
#          'PERSON': 41,
#          'ORG': 47,
#          'DATE': 10,
#          'PRODUCT': 4,
#          'ORDINAL': 1,
#          'CARDINAL': 11,
#          'NORP': 15,
#          'TIME': 2,
#          'QUANTITY': 2,
#          'LOC': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('India', 18), ('China', 13), ('Chinese', 7)]

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# Car Reviews                                                                                Comparisons                                                                                                                                                                              Bikes                                                                                                              Bike News

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Car', 'NOUN', 'car'),
#  ('Reviews', 'PROPN', 'Reviews'),
#  ('                                                                               ',
#   'SPACE',
#   '                                                                               '),
#  ('Comparisons', 'NOUN', 'comparison'),
#  ('                                                                                                                                                                             ',
#   'SPACE',
#   '                                                                                                                                                                             '),
#  ('Bikes', 'PROPN', 'Bikes'),
#  ('                                                                                                             ',
#   'SPACE',
#   '                                                                                                             '),
#  ('Bike', 'PROPN', 'Bike'),
# ...

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[40])).ents])
# Out:
# {'Toch Singkam': 'PERSON',
#  'Prasat Ringling': 'PERSON',
#  'Dongtu Ebiya': 'PERSON',
#  'Tanu Baker': 'PERSON',
#  'Ngaru Diri': 'PERSON',
#  'Tagin': 'ORG'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(Car, 'O', ''), (Reviews, 'O', ''), (                                                                               , 'O', ''), (Comparisons, 'O', ''), (                                                                                                                                                                             , 'O', ''), (Bikes, 'O', ''), (                                                                                                             , 'O', ''), (Bike, 'O', ''), (News, 'O', ''), (                                                                               , 'O', '')]

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ﻿        '
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has never recognised
# ...
